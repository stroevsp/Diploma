# %% [markdown]
# # Мананников Н.Д.

# %% [markdown]
# ## Импорт

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from pymorphy2 import MorphAnalyzer

import glob
import re
import warnings
import pandas

warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Инициализация переменных

# %%
classes_list = []
proccesed_texts = []
texts = []
results = [0,0,0]
m = MorphAnalyzer()
regex = re.compile("[А-Яа-я]+")

# %% [markdown]
# ### Корпус стоп-слов

# %%
stopwords = ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так',
              'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 
              'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 
              'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж',
              'вам', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 
              'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'чего',
              'раз', 'тоже', 'себе', 'под', 'будет', 'ж', 'тогда', 'кто', 'этот', 'того', 'потому', 'этого',
              'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'сейчас',
              'были', 'куда', 'зачем', 'всех', 'никогда', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть',
              'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много',
              'разве', 'три', 'эту', 'моя', 'впрочем', 'хорошо', 'свою', 'этой', 'перед', 'иногда', 'лучше', 
              'чуть', 'том', 'нельзя', 'такой', 'им', 'более', 'всегда', 'конечно', 'всю', 'между']

# %% [markdown]
# ## Создание классов

# %%
class Text:
    
    text = ''
    category = ''
    
    def __init__(self, text, category):
        self.text = text
        self.category = category

# %%
class Text_proccesor:
    
    proccesed_text = ''
    
    def tokenize(text, regex=regex):
        proccesed_text = " ".join(regex.findall(text))
        proccesed_text = proccesed_text.lower()
        return(proccesed_text)

    
    def lemmatize(text):
        proccesed_text = [m.parse(word)[0].normal_form for word in text.split()]
        return(proccesed_text)
    
    def stopwords_remove(text):
        proccesed_text = ' '.join([token for token in text.split() if not token in stopwords])
        return(proccesed_text)

# %% [markdown]
# ## Подготовка данных для классификации

# %% [markdown]
# ### Получение списка текстов для обучения

# %%
#Указываем директорию и получаем список всех ее файлов
all_files = glob.glob('D:/Repo/Diploma/Data/Test/*.txt')

#Проходимся по списку путей, открываем каждый файл для чтения
for file in all_files:
    opened_file = open(file,'r')
    
    
    #Для каждого открытого файла инициализируем объект класса Text, в переменную text кладем 
    #текст документа, а в переменную category - ЗАГЛУШКУ
    classes_list.append(Text(opened_file.read(),'category'))

# %% [markdown]
# ### Получение текста для классификации

# %%
opened_file = open('target.txt','r')
target_text = opened_file.read()

# %% [markdown]
# ## Обработка текста

# %% [markdown]
# ### Очистка обучающих данных

# %%
for text in classes_list:
    tokenized_text = Text_proccesor.tokenize(text.text)
    no_stopwords = Text_proccesor.stopwords_remove(tokenized_text)
    proccesed_texts.append(' '.join(Text_proccesor.lemmatize(no_stopwords)))

# %% [markdown]
# ### Очистка классифицируемого текста

# %%
tokenized_target = Text_proccesor.tokenize(target_text)
no_stopwords_target = Text_proccesor.stopwords_remove(tokenized_target)
proccesed_target =(' '.join(Text_proccesor.lemmatize(no_stopwords_target)))

# %% [markdown]
# ## Процесс классификации

# %%
#Переносим тексты из объектов класса Text в список для классификации
for i in proccesed_texts:
    texts.append(i)



for i in range(100):
    texts_labels = [1,2,3]

    text_clf = Pipeline([
        ('tfidf',TfidfVectorizer()),
        ('clf', RandomForestClassifier())
    ])

    text_clf.fit(texts, texts_labels)


    result = text_clf.predict([proccesed_target])
    
    if result == 1:
        results[0] +=1
    if result == 2:
        results[1] +=1
    if result == 3:
        results[2] +=1
        
print(results)

# Обнуляем список текстов чтобы избежать ошибок при рестарте программы
texts = []  
proccesed_texts = []
results = [0,0,0]
# Out:
# [0, 98, 2]

# %%
print(proccesed_target)
# Out:
# итак начать основный сетевой термин такой сеть это совокупность устройство система который подключить друг друг логически физически общаться себя сюда отнести сервер компьютер телефон маршрутизатор далее размер сеть достигать размер интернет состоять два устройство соединить себя кабель каша разделить компонента сеть группа оконечный узел устройство который передавать принимать какой либо дать это мочь компьютер телефон сервер какой терминал тонкий клиент телевизор промежуточный устройство это устройство который соединять оконечный узел себя сюда отнести коммутатор концентратор модем маршрутизатор точка доступ сетевой среда это тот среда который происходить непосредственный передача дать сюда относиться кабель сетевой карточка различный род коннектор воздушный среда передача это медный кабель передача дать осуществляться помощь электрический сигнал оптоволоконный кабель помощь светов импульс беспроводный устройство помощь радиоволна посмотреть это картинка данный момент просто понимать отличие детальный отличие быть разобрать поздний взгляд главный вопрос использовать сеть ответ вопрос осветить самый популярный который использоваться повседневный жизнь приложение помощь приложение отправлять разный дать устройство открывать доступ общий ресурс это мочь консольный приложение приложение графический интерфейс сетевой ресурс это сетевой принтер который пример пользоваться офис сетевой камера который просматривать охрана находиться удалённый местность хранилище использовать сервер рабочий станция подключить сеть создаваться хранилище доступный другой многие человек выкладывать туда свой файл видео картинка открывать общий доступ другой пользователь пример который ход приходить голова это диск яндекс диск тот подобный сервис резервный копирование часто крупный компания использовать центральный сервер компьютер копировать важный файл резервный копия это нужно последующий восстановление дать оригинал удалиться повредиться метод копирование огромный количество предварительный сжатие кодирование далее телефония работать протокол применяться повсеместно простой дешёвый традиционный телефония каждый год вытеснять список чаща многие работать именно приложение поэтому разобрать подробно старательно быть выбирать тот приложение который связать сеть поэтому приложение тип калькулятор блокнот внимание брать загрузчик это файловый менеджер работать протокол банальный пример это скачивание фильм музыка картинка файлообменник иной источник категория отнести резервный копирование который автоматически делать сервер каждый ночь это встроить сторонний программа утилит который выполнять копирование скачивание данный вид приложение требовать прямой человеческий вмешательство достаточно указать место сохранить скачивание сам начаться закончиться скорость скачивание зависеть пропускной способность данный тип приложение это критично например файл скачиваться минута вопрос время целостность файл это никак сказаться сложность мочь возникнуть мы пара часы сделать резервный копия система плохой канал соответственно низка пропускной способность это занимать несколько день ниже привести описание самый популярный протокол дать группа это стандартный протокол передача дать установление соединение работать протокол протокол дальнейший подробно рассмотреть стандартный номер порт чаща использоваться загрузка сайт веб хостинг выгрузка самый популярный приложение работать это протокол это выглядеть сам приложение это упрощённый версия протокол который работать установление соединение протокол применяться загрузка образ бездисковый рабочий станция особенно широко использоваться устройство тот загрузка образ резервный копия интерактивный приложение приложение позволять осуществить интерактивный обмен например модель человек человек человек помощь интерактивный приложение общаться себя вести общий работа сюда относиться электронный почта форум который несколько эксперт помогать человек решение вопрос модель человек машина человек общаться непосредственно компьютер это у ...
